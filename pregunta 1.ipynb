# %% [markdown]
# ### pregunta 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

allstate = pd.read_csv(r"C:\Users\Gustavo\Documents\UFM\tercer semestre\data science\allstate.csv")
allstate.head()

allstate.info
allstate.cost.describe()
allstate.mode()

# evalue la informacion de allstpate con describe y se observa que el primer cuartil de cost es 605, 
# entonces evaluaré en que estado esta el seguro más barato y más repetido. 

x = allstate[(allstate.cost<605)]

x.state.mode()

# el estado donde esta la moda en cuanto al seguro abajo de 605 (lo más barato) es en Florida


x.car_value.mode()
#valor de los carros más repetidos en cuanto a los más baratos bajo de 605 es clase (E)

sns.distplot(x.age_oldest)
x.age_oldest.describe()


youngest= x[(x.age_oldest<75)]
print youngest
sns.distplot(youngest.age_oldest)
youngest.age_oldest.mode()
# en los resultados de las graficas se puede concluir que las personas de mayor edad son más baratas de asegurar.
# Out:
#         customer_ID  shopping_pt  record_type  day   time state  location  \
# 22         10000007            8            1    4  14:26    PA     10008
# 27         10000014            1            0    4  16:30    MO     10015
# 28         10000014            2            0    4  16:31    MO     10015
# 29         10000014            3            0    4  16:32    MO     10015
# 30         10000014            4            0    4  16:35    MO     10015
# 31         10000014            5            0    4  16:43    MO     10015
# 33         10000016            1            0    2  13:34    OH     10017
# 34         10000016            2            0    2  13:35    OH     10017
# 35         10000016            3            0    2  13:35    OH     10017
# 36         10000016            4            0    2  13:36    OH     10017
# 37         10000016            5            0    2  13:39    OH     10017
# 38         10000016            6            0    2  13:42    OH     10017
# 39         10000016            7            0    2  13:43    OH     10017
# 40         10000016            8            0    2  13:44    OH     10017
# 41         10000016            9            0    2  13:47    OH     10017
# 42         10000016           10            1    3  13:15    OH     10018
# 59         10000025            2            0    0  15:06    OH     10027
# 60         10000025            3            0    0  15:07    OH     10027
# 61         10000025            4            0    0  15:08    OH     10027
# 62         10000025            5            0    0  15:10    OH     10027
# 63         10000025            6            0    0  15:16    OH     10027
# 64         10000025            7            1    0  15:26    OH     10027
# 65         10000026            1            0    1  09:09    OH     10028
# 66         10000026            2            0    1  09:09    OH     10028
# 67         10000026            3            0    1  09:10    OH     10028
# 68         10000026            4            1    3  15:24    OH     10028
# 69         10000027            1            0    0  09:11    IN     10029
# 71         10000027            3            0    0  09:13    IN     10029
# 89         10000032            1            0    0  18:15    OR     10034
# 90         10000032            2            0    0  18:15    OR     10034
# ...             ...          ...          ...  ...    ...   ...       ...
# 665026     10152680            8            0    1  15:46    ID     12348
# 665027     10152680            9            0    1  15:49    ID     12348
# 665028     10152680           10            1    3  10:44    ID     12348
# 665063     10152689            1            0    4  15:52    OH     10601
# 665090     10152692            1            0    0  15:22    FL     11356
# 665091     10152692            2            0    0  15:22    FL     11356
# 665092     10152692            3            0    0  15:24    FL     11356
# 665093     10152692            4            1    0  10:28    FL     11356
# 665104     10152694            1            0    0  15:26    TN     10827
# 665109     10152697            1            0    0  14:44    NM     15049
# 665142     10152702            1            0    3  15:00    FL     11337
# 665143     10152702            2            0    3  15:01    FL     11337
# 665144     10152702            3            0    3  15:04    FL     11337
# 665145     10152702            4            0    3  15:06    FL     11337
# 665146     10152702            5            0    3  15:06    FL     11337
# 665147     10152702            6            0    3  15:17    FL     11337
# 665148     10152702            7            0    3  15:20    FL     11337
# 665149     10152702            8            1    3  15:34    FL     11337
# 665159     10152704            1            0    4  12:32    NH     10709
# 665160     10152704            2            0    4  12:33    NH     10709
# 665161     10152704            3            0    4  12:35    NH     10709
# 665162     10152704            4            1    1  13:18    NH     10709
# 665164     10152706            2            0    0  16:43    AL     10476
# 665165     10152706            3            0    0  16:59    AL     10476
# 665184     10152710            4            0    1  12:10    OH     12597
# 665185     10152710            5            0    1  12:11    OH     12597
# 665186     10152710            6            0    1  12:12    OH     12597
# 665187     10152710            7            0    1  12:13    OH     12597
# 665189     10152710            9            0    1  12:15    OH     12597
# 665190     10152710           10            1    3  15:57    OH     12597
#
#         group_size  homeowner  car_age  ...  C_previous  duration_previous  A  \
# 22               1          0       11  ...         2.0                4.0  0
# 27               1          0        5  ...         1.0                2.0  1
# 28               1          0        5  ...         1.0                2.0  2
# 29               1          0        5  ...         1.0                2.0  1
# 30               1          0        5  ...         1.0                2.0  1
# 31               1          0        5  ...         1.0                2.0  1
# 33               1          0        6  ...         3.0                9.0  1
# 34               1          0        6  ...         3.0                9.0  2
# 35               1          0        6  ...         3.0                9.0  2
# 36               1          0        6  ...         3.0                9.0  2
# 37               1          0        6  ...         3.0                9.0  2
# 38               1          0        6  ...         3.0                9.0  2
# 39               1          0        6  ...         3.0                9.0  2
# 40               1          0        6  ...         3.0                9.0  2
# 41               1          0        6  ...         3.0                9.0  2
# 42               1          0        6  ...         3.0                9.0  2
# 59               2          1       15  ...         3.0                0.0  0
# 60               2          1       15  ...         3.0                0.0  0
# 61               2          1       15  ...         3.0                0.0  0
# 62               2          1       15  ...         3.0                0.0  0
# 63               2          1       15  ...         3.0                0.0  0
# 64               2          1       15  ...         3.0                0.0  0
# 65               2          1        5  ...         3.0                1.0  1
# 66               2          1        5  ...         3.0                1.0  1
# 67               2          1        5  ...         3.0                1.0  1
# 68               2          1        5  ...         3.0                1.0  1
# 69               1          0       17  ...         2.0                1.0  0
# 71               1          0       17  ...         2.0                1.0  0
# 89               1          1       12  ...         4.0               14.0  1
# 90               1          1       12  ...         4.0               14.0  2
# ...            ...        ...      ...  ...         ...                ... ..
# 665026           1          0       10  ...         1.0                4.0  0
# 665027           1          0       10  ...         1.0                4.0  0
# 665028           1          0       10  ...         1.0                4.0  0
# 665063           2          0        6  ...         2.0               15.0  1
# 665090           1          1        9  ...         3.0                7.0  1
# 665091           1          1        9  ...         3.0                7.0  1
# 665092           1          1        9  ...         3.0                7.0  1
# 665093           1          1        9  ...         3.0                7.0  1
# 665104           1          1        2  ...         3.0                4.0  1
# 665109           1          1        6  ...         3.0                5.0  0
# 665142           1          1        2  ...         4.0                1.0  1
# 665143           1          1        2  ...         4.0                1.0  1
# 665144           1          1        2  ...         4.0                1.0  1
# 665145           1          1        2  ...         4.0                1.0  1
# 665146           1          1        2  ...         4.0                1.0  1
# 665147           1          1        2  ...         4.0                1.0  1
# 665148           1          1        2  ...         4.0                1.0  1
# 665149           1          1        2  ...         4.0                1.0  1
# 665159           2          1       23  ...         3.0               15.0  1
# 665160           2          1       23  ...         3.0               15.0  0
# 665161           2          1       23  ...         3.0               15.0  0
# 665162           2          1       23  ...         3.0               15.0  0
# 665164           2          1       14  ...         3.0                2.0  0
# 665165           2          1       14  ...         3.0                2.0  0
# 665184           1          0        9  ...         3.0                2.0  0
# 665185           1          0        9  ...         3.0                2.0  0
# 665186           1          0        9  ...         3.0                2.0  0
# 665187           1          0        9  ...         3.0                2.0  0
# 665189           1          0        9  ...         3.0                2.0  0
# 665190           1          0        9  ...         3.0                2.0  0
#
#         B  C  D  E  F  G  cost
# 22      0  1  2  0  0  1   602
# 27      1  3  3  0  2  2   604
# 28      1  1  1  0  2  2   585
# 29      1  1  1  0  2  2   603
# 30      1  1  1  0  2  2   603
# 31      1  1  1  0  2  2   603
# 33      1  3  3  0  1  3   590
# 34      1  3  3  1  3  3   584
# 35      1  3  3  1  3  3   591
# 36      1  3  3  1  3  3   591
# 37      1  3  3  1  3  3   591
# 38      1  3  3  1  3  3   591
# 39      1  3  3  1  3  3   585
# 40      1  3  3  1  3  3   591
# 41      0  3  3  1  3  3   589
# 42      0  3  3  0  3  3   597
# 59      0  1  3  0  0  3   584
# 60      0  1  3  0  0  3   601
# 61      0  1  1  0  0  3   600
# 62      0  1  1  0  0  3   600
# 63      0  1  1  0  0  3   600
# 64      0  1  1  0  0  3   604
# 65      0  3  3  0  2  3   556
# 66      0  3  3  0  2  3   556
# 67      1  3  3  1  2  3   572
# 68      1  3  3  1  2  3   578
# 69      0  1  1  0  0  2   575
# 71      0  2  2  0  0  2   598
# 89      1  3  3  0  1  2   594
# 90      1  3  3  0  3  2   585
# ...    .. .. .. .. .. ..   ...
# 665026  0  1  2  0  0  1   567
# 665027  0  1  2  0  0  1   567
# 665028  0  1  2  0  0  1   567
# 665063  0  1  1  0  2  3   596
# 665090  1  2  3  0  2  4   550
# 665091  1  3  3  1  1  4   582
# 665092  1  3  3  1  1  4   585
# 665093  1  3  3  1  1  4   585
# 665104  1  1  1  1  2  1   596
# 665109  0  1  1  0  0  4   589
# 665142  1  1  3  0  1  3   549
# 665143  1  3  3  0  2  3   579
# 665144  1  4  3  0  2  3   581
# 665145  1  4  3  0  2  3   583
# 665146  1  4  3  0  2  3   583
# 665147  1  4  3  0  2  3   583
# 665148  1  4  3  0  2  3   583
# 665149  1  4  3  0  2  4   592
# 665159  0  3  3  0  1  1   522
# 665160  0  3  3  0  0  1   489
# 665161  0  3  3  0  0  1   489
# 665162  0  3  3  0  0  2   500
# 665164  0  2  2  0  0  1   602
# 665165  0  2  2  0  0  1   602
# 665184  0  3  3  0  1  3   589
# 665185  0  3  3  0  1  3   596
# 665186  0  3  3  0  1  3   602
# 665187  0  3  3  0  1  3   602
# 665189  0  3  3  0  1  3   603
# 665190  0  3  3  0  1  3   603
#
# [154248 rows x 25 columns]
# 0    64
# dtype: int64
